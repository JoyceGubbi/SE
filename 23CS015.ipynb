# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyceGubbi/SE/blob/main/23CS015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
doc=nlp("AI is simulation of human inteligence by machine.It includes explore nlp speech recognisation and machine")
grams=ngrams(doc,2)
print(list('Bigrams'))
# Out:
# ['B', 'i', 'g', 'r', 'a', 'm', 's']

# %%
import spacy
from nltk import ngrams
nlp=spacy.load('en_core_web_sm')
doc=nlp("AI is simulation of human inteligence by machine.It includes explore nlp speech recognisation and machine")
grams=ngrams(doc,3)
print(list('Trigrams'))
# Out:
# ['T', 'r', 'i', 'g', 'r', 'a', 'm', 's']
